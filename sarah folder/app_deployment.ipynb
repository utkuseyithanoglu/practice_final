# %%
import streamlit as st
import pandas as pd

# %% [markdown]
# ### Key inclusions:
# - call volume visualizations
# - response time predictons

# %%
# Re-use the CSV in your code executions!
read_and_cache_csv = st.cache(pd.read_csv)
# Out:
# 2026-02-24 01:34:44.719 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-24 01:34:44.839
# ...
#   command:
#
#     streamlit run /home/codespace/.local/lib/python3.12/site-packages/ipykernel_launcher.py [ARGUMENTS]
# 2026-02-24 01:34:44.840 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-24 01:34:44.841 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-24 01:34:44.841
# `st.cache` is deprecated and will be removed soon. Please use one of Streamlit's new
# caching commands, `st.cache_data` or `st.cache_resource`. More information
# [in our docs](https://docs.streamlit.io/develop/concepts/architecture/caching).
#
# **Note**: The behavior of `st.cache` was updated in Streamlit 1.36 to the new caching
# logic used by `st.cache_data` and `st.cache_resource`. This might lead to some problems
# ...

# %%
display_data = read_and_cache_csv('../data/raw/ems_2025_merged.csv')
# Out:
#    incident_id             datetime initial_type  initial_severity final_type  \
# 0    250010001  2025-01-01 00:00:12       STNDBY                 8     STNDBY
# 1    250010003  2025-01-01 00:01:53          UNC                 2        UNC
# 2    250010004  2025-01-01 00:01:58         CARD                 3       CARD
# 3    250010007  2025-01-01 00:03:42        ABDPN                 5      ABDPN
# 4    250010008  2025-01-01 00:04:36       STATEP                 2     STATEP
#
#    final_severity          assignment_time valid_dispatch_response  \
# 0               8  2025-01-01T09:53:41.000                       N
# 1               2  2025-01-01T00:02:06.000                       Y
# 2               3  2025-01-01T00:01:58.000                       Y
# 3               5  2025-01-01T00:03:59.000                       Y
# 4               2  2025-01-01T00:05:06.000                       Y
#
#    dispatch_response_sec          activation_time  ...        datetime_hour  \
# ...

# %% [markdown]
# Dataframe display:
# - number of calls by borough
# - average response time by hour by borough
# - by season
# - by initial severity

# %%
# Dataframe exploration example

# %%
#plots

# %%
# New york mappings

# %% [markdown]
# # Reference

# %%
"""import os
import pickle

os.makedirs("../data/models", exist_ok=True)

models = {
    "winter": winter_model,
    "spring": spring_model,
    "summer": summer_model,
    "fall": fall_model}

with open("../data/models/season_models.pkl", "wb") as f:
    pickle.dump(models, f)"""
